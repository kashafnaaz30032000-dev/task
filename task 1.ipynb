# %%
import pandas as pd

# %%
df= pd.read_csv(r"C:\Users\aditi\my desktop\desktop\D08-HealthInfrastructure_1.csv")

# %%
df.head()
# Out:
#   City Name  Zone Name                        Ward Name  Ward No.  \
# 0    RAIPUR          1               YATIYATAN LAL WARD         4
# 1    RAIPUR          1                BANJARI MAMA WARD         5
# 2    RAIPUR          1        VIRANGNA AVA.NTI BAI WARD         6
# 3    RAIPUR          1                VIR SHIVAJI WARD          7
# 4    RAIPUR          1  NETAJI KANHAIYALAL BAZARI WARD          8
#
#       Facility Name Type  (Hospital / Nursing Home / Lab)  \
# 0  om hari hospital                               Nursing
# 1       jk hospital                              Hospital
# 2       ak hospital                               Nursing
# 3       mr hospital                              Hospital
# 4  om hari hospital                               Nursing
#
#    Class : (Public / Private) Level (Primary / Secondary / Tertiary)  \
# 0                     Private                               Tertiary
# 1                     Private                               Tertiary
# ...

# %%
df.tail()
# Out:
#      City Name  Zone Name                 Ward Name  Ward No.  \
# 1339   Udaipur          4  al Bahudur Shashtri Ward        51
# 1340   Udaipur          4  al Bahudur Shashtri Ward        52
# 1341   Udaipur          5  al Bahudur Shashtri Ward        53
# 1342   Udaipur          5  al Bahudur Shashtri Ward        54
# 1343   Udaipur          5  al Bahudur Shashtri Ward        55
#
#                    Facility Name Type  (Hospital / Nursing Home / Lab)  \
# 1339    Arogyam Ayurved Hospital                              Hospital
# 1340      Dr. Atray Eye Hospital                              Hospital
# 1341        Partani Ent Hospital                              Hospital
# 1342            Hari Om Hospital                              Hospital
# 1343  Shantiraj Hospital Pvt Ltd                              Hospital
#
#       Class : (Public / Private) Level (Primary / Secondary / Tertiary)  \
# 1339                     Private                               Tertiary
# ...

# %%
df.shape
# Out:
# (1344, 17)

# %%
df.columns
# Out:
# Index(['City Name', 'Zone Name', 'Ward Name', 'Ward No.', 'Facility Name',
#        'Type  (Hospital / Nursing Home / Lab)', ' Class : (Public / Private)',
#        'Level (Primary / Secondary / Tertiary)', 'Pharmacy Available : Yes/No',
#        'Number of Beds in Emergency Wards ', 'Number of Beds in facility type',
#        'Number of Doctors / Physicians', 'Number of Nurses',
#        'Number of Midwives Professional ', 'Average Monthly Patient Footfall',
#        'Ambulance Service Available', 'Count of Ambulance'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1344 entries, 0 to 1343
# Data columns (total 17 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   City Name                               1344 non-null   object
#  1   Zone Name                               1344 non-null   int64
#  2   Ward Name                               1344 non-null   object
#  3   Ward No.                                1344 non-null   int64
#  4   Facility Name                           1344 non-null   object
#  5   Type  (Hospital / Nursing Home / Lab)   1344 non-null   object
#  6    Class : (Public / Private)             1344 non-null   object
#  7   Level (Primary / Secondary / Tertiary)  1344 non-null   object
#  8   Pharmacy Available : Yes/No             1344 non-null   object
#  9   Number of Beds in Emergency Wards       1344 non-null   int64
# ...
